# %%
import cv2
import numpy as np
# for green color
green = np.uint8([[[0,255,0 ]]])
hsv_green = cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
print(hsv_green)

#for red color
red=np.uint8([[[0,0,255]]])
hsv_red=cv2.cvtColor(red,cv2.COLOR_BGR2HSV)
print(hsv_red)

#for yellow color
yellow=np.uint8([[[0,255,255]]])
hsv_yellow=cv2.cvtColor(yellow,cv2.COLOR_BGR2HSV)
print(hsv_yellow)

#for orange color
orange=np.uint8([[[255,165,0]]])
hsv_orange=cv2.cvtColor(orange,cv2.COLOR_BGR2HSV)
print(hsv_orange)

#opening camera

# %%
import cv2
import numpy as np

green = np.uint8([[[0,255,0 ]]])
red=np.uint8([[[0,0,255]]])
yellow=np.uint8([[[0,255,255]]])
orange=np.uint8([[[255,165,0]]])
#  range of red color in HSV
lower_red = np.array([0,50,50])
upper_red = np.array([255,10,10])
#  range of yellow color in HSV
lower_yellow = np.array([0,50,50])
upper_yellow = np.array([255,10,10])
#  range of green color in HSV
lower_green = np.array([36,0,0])
upper_green = np.array([70,255,255])
#  range of orange color in HSV
lower_orange = np.array([0,50,50])
upper_orange = np.array([255,10,10])
 
lower_yellow = np.array([0,50,50])
upper_yellow = np.array([255,10,10])

cap = cv2.VideoCapture(0)    
while(True):
     
 # Take each frame
    ret,frame = cap.read()
    
 #HSV ranges of red,green,yellow,orange
    hsv_red=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    hsv_green = cv2.cvtColor(green,cv2.COLOR_BGR2HSV)
    hsv_yellow=cv2.cvtColor(yellow,cv2.COLOR_BGR2HSV)
    hsv_orange=cv2.cvtColor(orange,cv2.COLOR_BGR2HSV)
     
 # Threshold the HSV image to get only red colors
    maskr = cv2.inRange(hsv_red, lower_red, upper_red)
    masky = cv2.inRange(hsv_yellow, lower_yellow, upper_yellow)
    maskg = cv2.inRange(hsv_green, lower_green, upper_green)
    masko = cv2.inRange(hsv_orange, lower_orange, upper_orange)
    mask=maskr+maskg
   
    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break
    
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):
    yellow=np.uint8([[[0,255,255]]])
    # Take each frame
    ret, frame = cap.read()

    # Convert BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    #  range of red color in HSV
    lower_red = np.array([0,50,50])
    upper_red = np.array([10,255,255])
    red_mask = cv2.inRange(hsv, lower_red, upper_red)
    
    lower_green = np.array([50, 50, 120])
    upper_green = np.array([70, 255, 255]) 
    green_mask = cv2.inRange(hsv, lower_green, upper_green) # I have the Green threshold image.
    
    lower_yellow = np.array([20,100,100])
    upper_yellow = np.array([30,255,255])
    yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)
    # Threshold the HSV image to get only blue colors
    
    mask = red_mask + green_mask+ yellow_mask
    #mask1= yellow_mask1 + red_mask
    # Bitwise-AND mask and original image
    res = cv2.bitwise_or(frame,frame, mask= mask)
    #res1 = cv2.bitwise_or(frame,frame, mask1= mask1)
    k=hsv[0][1][0]
    l=hsv[1][1][1]
    
    if(70<k<=100):
        print('RED',k)
            
    if(20<l<=50):
        print('YELLOW',l)
            
        
    #print(hsv.getPixel(00))
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    #cv2.imshow('mask1',mask1)
    #cv2.imshow('res1',res1)
    #print('mask',mask)
    #print('mask dim',mask.ndim)
    
    #print('res',res)
    #print('res dim',res.ndim)
    #if(res.ndim==3):
    #print(mask)
  
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
# Out:
# RED 83
# YELLOW 32
# RED 99
# RED 90
# YELLOW 28
# RED 86
# YELLOW 34
# RED 90
# RED 83
# YELLOW 38
# RED 99
# RED 83
# YELLOW 32
# RED 81
# YELLOW 27
# RED 86
# YELLOW 32
# RED 80
# YELLOW 32
# RED 85
# YELLOW 37
# RED 87
# YELLOW 28
# RED 74
# YELLOW 26
# RED 99
# YELLOW 27
# RED 85
# RED 83
# YELLOW 27
# RED 81
# RED 85
# YELLOW 37
# RED 85
# RED 87
# YELLOW 27
# RED 83
# YELLOW 40
# RED 83
# YELLOW 31
# RED 83
# YELLOW 26
# RED 83
# YELLOW 36
# RED 85
# RED 85
# RED 97
# YELLOW 27
# RED 86
# YELLOW 27
# RED 86
# YELLOW 30
# RED 87
# YELLOW 26
# RED 83
# YELLOW 27
# RED 87
# YELLOW 30
# RED 100
# YELLOW 25
# RED 91
# YELLOW 36
# RED 87
# YELLOW 26
# RED 87
# YELLOW 26
# RED 85
# YELLOW 36
# RED 80
# YELLOW 30
# RED 83
# YELLOW 30
# RED 87
# YELLOW 27
# RED 93
# YELLOW 32
# RED 90
# RED 80
# YELLOW 30
# RED 80
# YELLOW 26
# RED 80
# YELLOW 26
# RED 80
# YELLOW 26
# YELLOW 25
# RED 74
# YELLOW 31
# RED 100
# RED 85
# YELLOW 36
# RED 83
# YELLOW 26
# RED 100
# RED 83
# YELLOW 26
# ...
